# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
from imgtools import *

# %%
my_path1 = 'D:/python/AI/img/01/01.JPG'
my_path2 = 'D:/python/AI/img/01/new_01.PNG'

# %%
image_list = [my_path1,my_path2]
result_img = average_imgae(image_list)
display(result_img)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>
