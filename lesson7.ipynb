# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from PIL import Image
from imgtools import *

# %%
my_path = 'D:/python/AI/img/01/01.JPG'
img = load_image(my_path)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>

# %%
print(img.size)
# Out:
# (275, 183)

# %%
img.resize((550,366))
# Out:
# <PIL.Image.Image image mode=RGB size=550x366>

# %%
plt.imshow(img)

# %%
x = [1,2,3,4,5]
y = [10,16,20,30,25]
plt.plot(x,y,color="red")
plt.title("HAHA")
plt.axis("OFF")
plt.show()

# %%
note_img = load_image("D:/python/AI/img/01/Capture.PNG")
display(note_img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1586x639>

# %%
x = [100,100,200,200]
y = [70,100,100,60]
plt.imshow(img)
plt.plot(x,y,"c*") # Hiển thị dấu *
plt.plot(x,y,"c*--")
