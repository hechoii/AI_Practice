# %%
from PIL import Image
from imgtools import *

# %%
# Thư mục chứa hình ảnh
dir = 'D:/python/AI/img/01'

# %%
# Đọc nhiều ảnh từ dir
imgs = get_image_list(dir)

# %%
for img in imgs:
    display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=183x275>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=275x183>

# %% [markdown]
# # dưới là làm trước trên là làm sau

# %%
image_path = dir + '/01.JPG'
print(image_path)
# Out:
# D:/python/AI/img/01/01.JPG

# %%
# Dùng Image.open(path) để đọc ảnh
img01 = load_image(image_path)

# %%
img01.show()

# %%
print("Định dạng ảnh ", img01.format)
# Out:
# Định dạng ảnh  JPEG

# %%
print("Kích thước hình ảnh ", img01.size)
# Out:
# Kích thước hình ảnh  (275, 183)

# %%
# Lưu ảnh
new_image_JPG = dir + '/new_01.JPG'
new_image_PNG = dir + '/new_01.PNG'
img01.save(new_image_PNG)

# %%
# Đóng tập tin
img01.close()
