# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
my_path = 'D:/python/AI/img/01/01.JPG'
avata = 'D:/python/AI/img/01/avata.JPG'

# %%
img = Image.open(my_path)
plt.imshow(img)

# %%
gray_img = img.convert("L")
plt.imshow(grey_img,cmap="gray")

# %%
im_array = np.array(gray_img)
print(im_array)
# Out:
# [[ 9  9 10 ... 46 46 46]
#  [10 10 11 ... 45 45 45]
#  [11 12 13 ... 43 43 43]
#  ...
#  [45 45 45 ... 10 10  9]
#  [44 44 45 ... 10 10  9]
#  [44 44 44 ... 10 10  9]]

# %%
# Tạo một hình vẽ mới:
plt.figure()
plt.hist(im_array.flatten(),bins=128) # flatten biến mảng 2 chiều thành mảng 1 chiều, bins là số lượng ngăn
plt.title("Biểu đồ histogram của ảnh")
plt.xlabel("Giá trị của pixel")
plt.ylabel("Số lượng")
# Out:
# Text(0, 0.5, 'Số lượng')

# %%
avata_gray = Image.open(avata).convert("L")
# làm nổi bật đường biên:
plt.figure()
plt.gray()
plt.contour(gray_img,origin="image")
plt.show()

# %%
avata_gray = Image.open(avata).convert("L")
plt.imshow(avata_gray)

# Tạo hình vẽ mới:
plt.figure()
plt.gray()
plt.contour(avata_gray,origin="image")
plt.axis("equal") # Đảm bảo trục x y bằng nhau
plt.show()
