# %%
from PIL import Image
from imgtools import *
from IPython.display import display

# %%
# Đường dẫn ảnh
my_path = 'D:/python/AI/img/01/01.JPG'

# %%
img = load_image(my_path)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>

# %%
print(img.size)
# Out:
# (275, 183)

# %%
# Xoay ảnh
resize_img = img.resize((500,500))
rotate_img = resize_img.rotate(-90)
display(rotate_img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %%
tranpose_img = img.transpose(Image.Transpose.ROTATE_90)
display(tranpose_img)
# Out:
# <PIL.Image.Image image mode=RGB size=183x275>
