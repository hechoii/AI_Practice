# %%
import cv2

# %%
path_video = 'D:/python/AI/img/01/videocat.mp4'

# %%
my_vid = cv2.VideoCapture(path_video)
# Tạo cửa sổ để hiện thị
cv2.namedWindow("Video Player", cv2.WINDOW_NORMAL)

# %%
# Ghi text:
content = f"FPS: {fps:.2f}"
font = cv2.FONT_HERSHEY_SIMPLEX
font_color = (255,255,255)
font_thickness = 2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Ghi text:
# ----> 2 content = f"FPS: {fps:.2f}"
#       3 font = cv2.FONT_HERSHEY_SIMPLEX
#       4 font_color = (255,255,255)
#
# NameError: name 'fps' is not defined

# %%
# Hiển thị từng khung ảnh 1:
while True:
    ref, frame = my_vid.read()
    # Tháot khi không thể đọc frame
    if not ref:
        break

    # Ghi số lượng FPS
    cv2.putText(frame,content.format(),(10,300),font,0.6,(255,255,255))
    # Hiển thị khung ảnh
    cv2.imshow("Video Player",frame)

    if(cv2.waitKey(10)==ord("q")):
        break

# %%
# Huỷ bỏ player
my_vid.release()
cv2.destroyAllWindows()
